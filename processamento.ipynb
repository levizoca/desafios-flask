# %%
### Importando bibliotecas

import pandas as pd

# %%
### Lendo arquivo e renomeando colunas

filename = 'K3241.K03200Y9.D30211.ESTABELE.csv'
columns = ['CNPJ BÁSICO',
           'CNPJ ORDEM ',
           'CNPJ DV',
           'IDENTIFICADOR MATRIZ/FILIAL',
           'NOME FANTASIA',
           'SITUAÇÃO CADASTRAL',
           'DATA SITUAÇÃO CADASTRAL',
           'MOTIVO SITUAÇÃO CADASTRAL',
           'NOME DA CIDADE NO EXTERIOR',
           'PAIS',
           'DATA DE INÍCIO ATIVIDADE ',
           'CNAE FISCAL PRINCIPAL',
           'CNAE FISCAL SECUNDÁRIA',
           'TIPO DE LOGRADOURO',
           'LOGRADOURO',
           'NÚMERO',
           'COMPLEMENTO',
           'BAIRRO',
           'CEP ',
           'UF',
           'MUNICÍPIO',
           'DDD 1 ',
           'TELEFONE 1',
           'DDD 2',
           'TELEFONE 2',
           'DDD DO FAX',
           'FAX ',
           'CORREIO ELETRÔNICO',
           'SITUAÇÃO ESPECIAL',
           'DATA DA SITUAÇÃO ESPECIAL']
df = pd.read_csv(filename, sep=';', names = columns, encoding='latin-1')
# Out:
# C:\Users\levim\AppData\Local\Temp\ipykernel_12204\1859180746.py:32: DtypeWarning: Columns (8,21,22,24,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, sep=';', names = columns, encoding='latin-1')

# %%
df.shape
# Out:
# (4753435, 32)

# %%
df.sample(10)
# Out:
#          CNPJ BÁSICO  CNPJ ORDEM   CNPJ DV  IDENTIFICADOR MATRIZ/FILIAL  \
# 3703737     22158052            1       23                            1
# 727395      48541057            1       24                            1
# 2626221      9730693            1       42                            1
# 2003245      7369685           27       26                            2
# 316384      44074196            1       34                            1
# 3916751     24688268            1       26                            1
# 3635256     21321516            1        8                            1
# 850821       5016783            1       15                            1
# 4730792     32407895            1       70                            1
# 662238      47852208            1        0                            1
#
#                               NOME FANTASIA  SITUAÇÃO CADASTRAL  \
# 3703737  BAR RESTAURANTE E MERCEARIA DO SOM                   2
# ...

# %%
### Criando colunas CNPJ COMPLETO e TELEFONE

df['CNPJ COMPLETO'] = df['CNPJ BÁSICO'].astype(str) + df['CNPJ ORDEM '].astype(str) + df['CNPJ DV'].astype(str)
df['TELEFONE'] = df['DDD 1 '].astype(str) + df['TELEFONE 1'].astype(str)


### Criando pivot_table apenas com as colunas que serão utilizadas

registros = df.pivot_table(
    index='CNPJ COMPLETO',
    values=['NOME FANTASIA', 'CEP ', 'TELEFONE', 'CORREIO ELETRÔNICO'],
    aggfunc='first'
)
registros.sample(10)
# Out:
#                      CEP                  CORREIO ELETRÔNICO  \
# CNPJ COMPLETO
# 3264410813     55590000.0         RICARDOFELIX7663@GMAIL.COM
# 45889365157     5874180.0  ESTERHONORIOSANTOS86398@GMAIL.COM
# 25936718115    57925000.0          FABIANEGORETT@HOTMAIL.COM
# 7263722188     20011030.0                               None
# 57926347187     6434140.0                               None
# 46073368180    20710180.0                MARCODOSS@GMAIL.COM
# 30496274184    59122241.0    CARNEIROCONSTRUCOES@OUTLOOK.COM
# 44516489124    31340290.0    CONTATODRIELLEFONSECA@GMAIL.COM
# 4642469185     70863520.0                               None
# 10798635130    57014550.0                               None
#
#                              NOME FANTASIA        TELEFONE
# CNPJ COMPLETO
# 3264410813           FRIGORIFICO ARCO-IRIS  81.035591173.0
# 45889365157              EXPRESSO PATINHAS  11.060569635.0
# 25936718115                           None            0.00
# ...

# %%
### Salvando arquivo em csv com apenas 10 registros

registros.sample(10).to_csv('estabelecimentos10.csv')

# %%
### Importando bibliotecas para conexão com o MongoDB

import pymongo
import json

# %%
### Transformando arquivo csv em json

df = pd.read_csv('estabelecimentos10.csv')
data = df.to_dict(orient = "records")
data
# Out:
# [{'CNPJ COMPLETO': 15865258128,
#   'CEP ': 29125350.0,
#   'CORREIO ELETRÔNICO': 'AILTOVARGAS@HOTMAIL.COM',
#   'NOME FANTASIA': 'PSOL - DIRETORIO MUNICIPAL DE VILA VELHA',
#   'TELEFONE': '27.098803100.0'},
#  {'CNPJ COMPLETO': 5061405614,
#   'CEP ': 1453010.0,
#   'CORREIO ELETRÔNICO': nan,
#   'NOME FANTASIA': nan,
#   'TELEFONE': 'nannan'},
#  {'CNPJ COMPLETO': 44715099183,
#   'CEP ': 45638000.0,
#   'CORREIO ELETRÔNICO': 'CLEITONSANTANA836@GMAIL.COM',
#   'NOME FANTASIA': 'DOM BARBUDO',
#   'TELEFONE': '73.081430711.0'},
#  {'CNPJ COMPLETO': 6749463137,
#   'CEP ': 60150161.0,
#   'CORREIO ELETRÔNICO': nan,
#   'NOME FANTASIA': 'ECONTELL',
#   'TELEFONE': '85.04639419'},
#  {'CNPJ COMPLETO': 95250569111,
#   'CEP ': 93336001.0,
#   'CORREIO ELETRÔNICO': nan,
#   'NOME FANTASIA': 'ELEBEEFE COMERCIO E REPRESENTACOES',
#   'TELEFONE': 'nannan'},
#  {'CNPJ COMPLETO': 12633518141,
#   'CEP ': 19806705.0,
#   'CORREIO ELETRÔNICO': 'WALDSONTEODORO@YHAOO.COM.BR',
# ...

# %%
### Conectando ao MongoDB

client = pymongo.MongoClient('mongodb://mongoadmin:password@localhost:27017/')
db = client['estabelecimentos']
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'estabelecimentos')

# %%
### Inserindo dados no MongoDB

db.dados.insert_many(data)
